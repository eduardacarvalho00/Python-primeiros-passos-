# %% [markdown]
# ## Logica de programação com Python

# %%
1+1
# Out:
# 2

# %%
nome = 'Eduarda'

# %%
nome
# Out:
# 'Eduarda'

# %%
idade = 17

# %%
print(f'Oi o meu nome é {nome} e tenho {idade} anos')
# Out:
# Oi o meu nome é Eduarda e tenho 17 anos

# %% [markdown]
# ## Criando minha primeira função

# %%
def saudacao():
  nome = input('Qual é o seu nome? ')
  print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual é o seu nome? Duda
# Olá Duda

# %%
def perguntas():
  nome = input('Qual é o seu nome? ')
  idade = input('Qual a sua idade? ')
  aonde = input('Em que cidade voçe mora? ')
  print(f'Olá {nome} que tem {idade} anos e mora em {aonde}, Prazer em te conhecer')

# %%
perguntas()
# Out:
# Qual é o seu nome? Duda
# Qual a sua idade? 17
# Em que cidade voçe mora? SP
# Olá Duda que tem 17 anos e mora em SP, Prazer em te conhecer

# %% [markdown]
# ## Parâmetros

# %%
nome = "Duda"

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Olá Duda

# %% [markdown]
# ## Condição

# %%
idade = 12

def verifica_se_pode_dirigir(idade):
  if idade >= 18: 
    print('Tem permissão para dirigir')
  else: print('Não tem permissão para dirigir')

# %%
verifica_se_pode_dirigir(idade)
# Out:
# Não tem permissão para dirigir

# %% [markdown]
# ## Convertendo tipo para inteiro

# %%
def verifica_se_pode_dirigir_sem_parametro():
  idade = input('Qual a sua idade? ')
  idade = int(idade)
  if idade >= 18: 
    print('Tem permissão para dirigir')
  else: print('Não tem permissão para dirigir')

verifica_se_pode_dirigir_sem_parametro()
# Out:
# Qual a sua idade? 0
# Não tem permissão para dirigir

# %% [markdown]
# ##Lista

# %%
idades = [16, 19, 69, 7]

# %%
idades[0:3]
# Out:
# [16, 19, 69]

# %%
idades[-2]
# Out:
# 69

# %%
idades[1:]
# Out:
# [19, 69, 7]

# %% [markdown]
# ## Laços e Loops

# %%
idades = [13, 28, 7, 58]

# %%
def verifica_se_pode_dirigir(idade):
 if idade >= 18: 
    print(f'{idade} anos de idade, TEM permissão para dirigir')
 else: 
    print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')

for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
# 13 anos de idade, NÃO TEM permissão para dirigir
# 28 anos de idade, TEM permissão para dirigir
# 7 anos de idade, NÃO TEM permissão para dirigir
# 58 anos de idade, TEM permissão para dirigir

# %%
def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18: 
      print(f'{idade} anos de idade, TEM permissão para dirigir')
    else: 
      print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')

verifica_se_pode_dirigir(idades)
# Out:
# 13 anos de idade, NÃO TEM permissão para dirigir
# 28 anos de idade, TEM permissão para dirigir
# 7 anos de idade, NÃO TEM permissão para dirigir
# 58 anos de idade, TEM permissão para dirigir

# %% [markdown]
# ## boleano

# %%
permissoes = []
idades = [20, 14, 45]

def verifica_se_pode_dirigir(idades, permissoes):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False) 

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True: 
    print('Tem permissão para dirigir')
  else: 
    print('Não tem permissão para dirigir')
# Out:
# Tem permissão para dirigir
# Não tem permissão para dirigir
# Tem permissão para dirigir

# %% [markdown]
# ## Tipos em uma lista

# %%
lista = ['Guilherme', 18, True, '45']

for elemento in lista:
  print(f'O elemento {elemento} é do tipo: ', type(elemento))
# Out:
# O elemento Guilherme é do tipo:  <class 'str'>
# O elemento 18 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 45 é do tipo:  <class 'str'>

# %% [markdown]
# ## Imports

# %%
from random import randrange, seed

# %%
seed(11)

# %%
randrange(0,11)
# Out:
# 7

# %%
notas_matematica = []

for notas in range(8):
  notas_matematica.append(randrange(0,11))

notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x= list(range(1, 9))
y = notas_matematica
plt.plot(x, y, marker='o')
plt.title('Notas de Matematica')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()
